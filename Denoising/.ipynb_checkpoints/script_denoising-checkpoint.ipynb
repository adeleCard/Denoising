# %%
# %%html
# <style>
# .container { width:80% !important; }
# </style>
# Out:
# <style>
# .container { width:80% !important; }
# </style>

# %%
from __future__ import division
import numpy as np
# %pylab inline
# %load_ext autoreload
# %autoreload 2
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# Clear signal :

# %%
plt.figure(figsize=(20, 3))
X = np.linspace(0, 10, 5000)
Y = np.load("./data/[DE-IDENTIFIED]_#DICOM#_0000A0A5_0926_000E_0926_286321_635440525514417877.dcm.npz")
Y = Y["data"][10]
plt.plot(X, Y)

# %% [markdown]
# Noisy signal :

# %%
plt.figure(figsize=(20, 3))
sigma = 0.04
Yb = Y + sigma * np.random.standard_normal(len(X))
plt.plot(X, Yb)

# %%
import utils
utils.snr(Y, Yb)
# Out:
# 16.517622893901894

# %% [markdown]
# Débruitage du signal :
#  Ici grâce à des ondelettes.

# %%
import pywt

# %%
L=8

# %%
plt.figure(figsize=(20, 3))
Yd = utils.waveFilter(Yb, sigma, L, 1.6)
L=8
plt.plot(Yd)
print utils.snr(Y,Yd)
# Out:
# 19.237809774

# %% [markdown]
# Détermination des pararamètres optimaux :

# %%
def filt (y, t):
    utils.waveFilter(y, sigma, L, t)
utils.opt(sigma, filt, Yb)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-4777e83d990a> in <module>()
#       1 def filt (y, t):
#       2     utils.waveFilter(y, sigma, L, t)
# ----> 3 utils.opt(sigma, filt, Yb)
#
# /home/cardiologs/Workspace/denoising/code/utils.py in opt(sigma, filt, y)
#      62     snrlist = np.zeros(len(M))
#      63     for i in np.arange(0, len(M)) :
# ---> 64         snrlist[i] = snr(y, filt(y, sigma));
#      65     plt.plot(M, snrlist)
#      66     i=np.argmax(snrlist)
#
# /home/cardiologs/Workspace/denoising/code/utils.py in snr(f0, f)
#      19         denoised signal
#      20     """
# ---> 21     return 20 * np.log10(np.linalg.norm(f0) / np.linalg.norm(f0 - f))
#      22
#      23 def gaussianFilter (y, mu) :
#
# TypeError: unsupported operand type(s) for -: 'float' and 'NoneType'
